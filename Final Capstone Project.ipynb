# %% [markdown]
# # Introduction/Business Problem

# %% [markdown]
# Road accident is considered to be a prevalent source of accident all across the world. Ironically, it is an accident that can be avoided most of the time since they often occur due to manmade reasons like negligence and carelessness. Therefore, it will be useful to develop an algorithim to predict the severity of an accident given the current weather, road and visibility conditions in order to remind drivers to be more careful. This will be extremely useful for the government/authorities managing road safety.

# %% [markdown]
# # Data

# %% [markdown]
# I will be using the shared data to do the analysis. The prediction will be made based on 'SEVERITYCODE' while analysing its relations with attributes such as 'WEATHER', 'ROADCOND' and 'LIGHTCOND'.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
